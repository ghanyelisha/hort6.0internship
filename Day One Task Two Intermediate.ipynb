# %% [markdown]
# # **Python Overview Full Exercises**

# %% [markdown]
# **1. Check If All Numbers Are Prime (Basic Python + Loops + Conditionals)**
# Write a function that takes a list of numbers and returns True if all numbers are prime, else False.
#
# Sample Input:
#
# ([0, 3, 4, 7, 9]) -> False
# ([3, 5, 7, 13]) -> True
# ([1, 5, 3]) -> False

# %%
# Out:
# True
# True
# True
# True
# True

# %% [markdown]
# **2. Sum of Even Numbers (Lists + Loops + Conditionals)**
# Write a program that accepts a list of integers and returns the sum of all even numbers.

# %%
# Out:
# The sum is 6

# %% [markdown]
# **3. Frequency Count of Characters (Dictionaries)**
# Given a string, write a function that counts the frequency of each character and stores results in a dictionary.
#
#
# Example: "hello" -> {'h':1, 'e':1, 'l':2, 'o':1}

# %%
# Out:
# 2
# ['h', 'e', 'l', 'l', 'o']
# [1, 1, 2, 2, 1]
# {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %% [markdown]
# **4. Senior Citizen Discount Check (Tuples + Conditionals)**
# Write a function that accepts a tuple (age, gender) and returns a string if the person is eligible for a senior citizen discount (age ≥ 60) and their gender category:
# Example: (65, 'M') -> "Eligible: True, Gender: Male"

# %%
# Out:
# Eligible:False  Gender:M

# %% [markdown]
# **5. Generate Random Numbers and Calculate Statistics (random + math)**
# Generate a list of 20 random integers between 1 and 100 using random.
#
# Calculate and print mean, median, and standard deviation using the math or statistics module.

# %%
# Out:
# [42, 22, 95, 21, 43, 81, 2, 53, 17, 4, 84, 97, 73, 51, 78, 33, 18, 10, 61, 38]
# The mean: 46.15
# The nedian: 42.5
# The standard deviation: 30.610068862867227

# %% [markdown]
# **6. Numpy Array Analysis (numpy + Lists)**
# Convert a list of integers from the previous exercises into a numpy array.
#
# Find the mean and standard deviation using np.mean() and np.std().
#
# Find indices of elements greater than the mean.

# %%
# Out:
# The mean: 46.15
# The nedian: 42.5
# The standard deviation: 29.835004608680723

# %% [markdown]
# **7. Explore NBA Player Dataset (pandas)**
# Load the dataset into a pandas DataFrame.
#
# Print the number of players (rows).
#
# Find and print the count of missing values for each column.
#
# List unique teams and positions in the dataset.
#
# Find and remove any duplicate records.
#
# Save the cleaned dataset to a new CSV file.

# %% [markdown]
# **8. Plot Player Salary Distribution (matplotlib + pandas)**
# Using the pandas DataFrame from #7, create a histogram of players’ salaries.
#
# Label the x-axis as “Salary” and y-axis as “Number of Players”.
#
# Add an appropriate title.

# %% [markdown]
# **9. List Comprehension Filter (Lists + Conditional Blocks)**
# Write a program using list comprehension that filters a list of numbers to return only those divisible by 3 but not by 6.

# %%
# Out:
# [21, 81, 51, 33]
# 21
# 81
# 51
# 33

# %%
# Out:
# ['Jones', 'Joel', 'Marian', 'Susan', 'Darius', 'Laurenta', 'Dylan', 'Geofrey']

# %% [markdown]
# **10. Multiplication Table with FizzBuzz Logic (Loops + Conditionals)**
# Create a multiplication table for numbers 1 to 5. For the product of each pair:
#
# Print "Fizz" if divisible by 3.
#
# Print "Buzz" if divisible by 5.
#
# Print "FizzBuzz" if divisible by both 3 and 5.
#
# Else print the product number.

# %%
# Out:
# 'Buzz'
