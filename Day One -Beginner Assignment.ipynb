# %% [markdown]
# # **Python Beginner Exercises (30 Exercises)**

# %% [markdown]
# ### **Section 1: Syntax & Output (Exercises 1-5)**

# %% [markdown]
# ### 1. Print statement
# **Start with:**
# ```python
# ```
#
# **Desired output:**
# ```
# Hello World
# ```

# %%
print ("Hello, World!")

#this is a single line comment


"""This is a multi-line comment

sfas

asdf
as
df or docstring"""

# %% [markdown]
# ### 2. Print with quotes
# **Start with:**
# ```python
# message = "Python"
# ```
#
# **Desired output:**
# ```
# "Python"
# ```

# %% [markdown]
# ### 3. Multiple print statements
# **Start with:**
# ```python
# ```
#
# **Desired output:**
# ```
# Line 1
# Line 2
# Line 3
# ```

# %% [markdown]
# ### 4. Print numbers
# **Start with:**
# ```python
# ```
#
# **Desired output:**
# ```
# 1 2 3 4 5
# ```

# %% [markdown]
# ### 5. Print with newline
# **Start with:**
# ```python
# words = "Hello World Python"
# ```
#
# **Desired output:**
# ```
# Hello
# World
# Python
# ```

# %% [markdown]
# ## **Section 2: Comments & Variables (Exercises 6-10)**

# %% [markdown]
# ### 6. Variable assignment
# **Start with:**
# ```python
# ```
#
# **Desired output:**
# ```
# 10
# ```

# %% [markdown]
# ### 7. Multiple variables
# **Start with:**
# ```python
# a = 5
# b = 3
# ```
#
# **Desired output:**
# ```
# 8
# ```

# %% [markdown]
# ### 8. Update variable
# **Start with:**
# ```python
# score = 0
# ```
#
# **Desired output:**
# ```
# 10
# ```

# %% [markdown]
# ### 9. Variable naming
# **Start with:**
# ```python
# first_name = "John"
# last_name = "Doe"
# ```
#
# **Desired output:**
# ```
# John Doe
# ```

# %% [markdown]
# ### 10. Constants (using ALL_CAPS)
# **Start with:**
# ```python
# PI = 3.14
# ```
#
# **Desired output:**
# ```
# 3.14
# ```

# %% [markdown]
# ## Section 3: Data Types & Numbers (Exercises 11-15)

# %% [markdown]
# ### 11. Integer operations
# **Start with:**
# ```python
# a = 10
# b = 3
# ```
#
# **Desired output:**
# ```
# 3
# ```

# %% [markdown]
# ### 12. Float division
# **Start with:**
# ```python
# x = 10
# y = 4
# ```
#
# **Desired output:**
# ```
# 2.5
# ```

# %% [markdown]
# ### 13. Mixed types
# **Start with:**
# ```python
# num = 5
# text = "5"
# ```
#
# **Desired output:**
# ```
# 55
# ```

# %% [markdown]
# ### 14. Large numbers
# **Start with:**
# ```python
# million = 1000000
# ```
#
# **Desired output:**
# ```
# 1000000
# ```

# %% [markdown]
# ### 15. Type checking
# **Start with:**
# ```python
# value = 42
# ```
#
# **Desired output:**
# ```
# <class 'int'>
# ```

# %% [markdown]
# ## **Section 4: Casting & Strings (Exercises 16-20)**

# %% [markdown]
# ### 16. Integer to string
# **Start with:**
# ```python
# num = 123
# ```
#
# **Desired output:**
# ```
# "123"
# ```

# %% [markdown]
# ### 17. String to integer
# **Start with:**
# ```python
# text = "42"
# ```
#
# **Desired output:**
# ```
# 42
# ```

# %% [markdown]
# ### 18. String concatenation
# **Start with:**
# ```python
# first = "Hello"
# second = "World"
# ```
#
# **Desired output:**
# ```
# HelloWorld
# ```

# %% [markdown]
# ### 19. String length
# **Start with:**
# ```python
# word = "Python"
# ```
#
# **Desired output:**
# ```
# 6
# ```

# %% [markdown]
# ### 20. String repetition
# **Start with:**
# ```python
# char = "*"
# ```
#
# **Desired output:**
# ```
# **********
# ```

# %% [markdown]
# ## **Section 5: Basic Math Operations (Exercises 21-25)**

# %% [markdown]
# ### 21. Addition
# **Start with:**
# ```python
# a = 15
# b = 25
# ```
#
# **Desired output:**
# ```
# 40
# ```

# %% [markdown]
# ### 22. Subtraction
# **Start with:**
# ```python
# balance = 100
# spent = 35
# ```
#
# **Desired output:**
# ```
# 65
# ```

# %% [markdown]
# ### 23. Multiplication
# **Start with:**
# ```python
# width = 5
# height = 8
# ```
#
# **Desired output:**
# ```
# 40
# ```

# %% [markdown]
# ### 24. Division
# **Start with:**
# ```python
# total = 100
# parts = 4
# ```
#
# **Desired output:**
# ```
# 25.0
# ```

# %% [markdown]
# ### 25. Modulo
# **Start with:**
# ```python
# number = 17
# divisor = 5
# ```
#
# **Desired output:**
# ```
# 2
# ```

# %% [markdown]
# ## **Section 6: Random & Lists Intro (Exercises 26-30)**

# %% [markdown]
# ### 26. Random number
# **Start with:**
# ```python
# import random
# ```
#
# **Desired output:**
# ```
# 37
# ```
# *(number between 30-40)*

# %% [markdown]
# ### 27. Random list (5 numbers)
# **Start with:**
# ```python
# import random
# ```
#
# **Desired output:**
# ```
# [32, 38, 35, 39, 31]
# ```
# *(5 random numbers 30-40)*

# %% [markdown]
# ### 28. Empty list
# **Start with:**
# ```python
# ```
#
# **Desired output:**
# ```
# []
# ```

# %% [markdown]
# ### 29. List with numbers
# **Start with:**
# ```python
# numbers = [1, 2, 3]
# ```
#
# **Desired output:**
# ```
# [1, 2, 3]
# ```

# %% [markdown]
# ### 30. List length
# **Start with:**
# ```python
# fruits = ["apple", "banana", "orange"]
# ```
#
# **Desired output:**
# ```
# 3
# ```
