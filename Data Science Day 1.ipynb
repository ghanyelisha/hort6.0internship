# %% [markdown]
# ## **Python Beginner Exercises**

# %% [markdown]
# ### 2. Addition with a message
#
# Start with:
#
# ```python
# a = 10
# b = 15
# ```
#
# Desired output:
#
# ```text
# The sum is 25
# ```

# %% [markdown]
# ### 3. Subtraction of two numbers
#
# Start with:
#
# ```python
# a = 9
# b = 4
# ```
#
# Desired output:
#
# ```text
# 5
# ```

# %% [markdown]
# ### 4. Subtraction with a message
#
# Start with:
#
# ```python
# x = 20
# y = 7
# ```
#
# Desired output:
#
# ```text
# The difference is 13
# ```

# %% [markdown]
# ### 5. Print statement with a variable
#
# Start with:
#
# ```python
# name = "Alice"
# ```
#
# Desired output:
#
# ```text
# Hello, Alice
# ```

# %% [markdown]
# ### 6. Print multiple variables
#
# Start with:
#
# ```python
# first_name = "John"
# age = 25
# ```
#
# Desired output:
#
# ```text
# John is 25 years old
# ```

# %% [markdown]
# ### 7. Store addition result in a variable
#
# Start with:
#
# ```python
# num1 = 4
# num2 = 6
# ```
#
# Desired output:
#
# ```text
# The result is 10
# ```

# %% [markdown]
# ### 8. Store subtraction result in a variable
#
# Start with:
#
# ```python
# start = 100
# spent = 30
# ```
#
# Desired output:
#
# ```text
# Remaining: 70
# ```

# %% [markdown]
# ### 9. Update variable using addition
#
# Start with:
#
# ```python
# score = 0
# points = 15
# ```
#
# Desired output:
#
# ```text
# New score: 15
# ```

# %% [markdown]
# ### 10. Update variable using subtraction
#
# Start with:
#
# ```python
# balance = 50
# withdraw = 20
# ```
#
# Desired output:
#
# ```text
# Balance left: 30
# ```

# %% [markdown]
# ### 1. Addition of two numbers
# Start with:
#
# ```python
# a = 5
# b = 3
# ```
# Desired output:
# ```text
# text
# 8
# ```
