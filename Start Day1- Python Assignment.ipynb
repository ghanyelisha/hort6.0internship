# %% [markdown]
# ## **Hort 6.0 30 Python Beginner Exercises**

# %% [markdown]
# 1.
# Write a Python statement that prints `Hello, World!`.

# %% [markdown]
# 2.
# Write a Python program to print your name and age on one line use a variable called `myName`, like:
# `My name is John and I am 20 years old`.

# %% [markdown]
# 3.
# Fix the indentation so this code runs without error and prints `5 is greater than 2`:
# ```python
# if 5 > 2:
# print("5 is greater than 2")
# ```

# %% [markdown]
# 4.
# Write a comment on one line, then print `Python is fun` on the next line.

# %% [markdown]
# 5.
# Add an inline comment at the end of this line explaining what it does:
# ```python
# print("Learning Python")
# ```

# %% [markdown]
# 6.
# Create a variable `x` with value `5` and a variable `y` with value `"Hello"`, then print both on separate lines.

# %% [markdown]
# 7.
# Create three variables `a`, `b`, and `c` on one line with values `1`, `2`, and `3`, then print them.

# %% [markdown]
# 8.
# Change the value of a variable `color` from `"red"` to `"blue"` and print the new value.

# %% [markdown]
# 9.
# Create variables of different data types: an `int`, a `float`, and a `str`, then print their types using `type()`.

# %% [markdown]
# 10.
# Given `x = "5"`, cast it to an integer and add `10` to it, then print the result `15`.

# %% [markdown]
# 11.
# Given `a = 7.9`, cast it to an integer and print the result.

# %% [markdown]
# 12.
# Given `num = 10`, cast it to a string and concatenate it with `" apples"` to print:
# `10 apples`.

# %% [markdown]
# 13.
# Create a variable `text = "Python"` and print its length and print using `len()`.

# %% [markdown]
# 14.
# Given `s = "Hello, World!"`, print only `Hello`.

# %% [markdown]
# 15.
# Given `s = "Python"`, use indexing to print the first character and the last character on separate lines.

# %% [markdown]
# 16.
# Given `first = "Hello"` and `last = "World"`, print `Hello World` with a space between using string concatenation.

# %% [markdown]
# 17.
# Given `name = "john"`, print it as `JOHN` using a string method.

# %% [markdown]
# 18.
# Given `sentence = "I love python"`, replace `"python"` with `"coding"` and print the new sentence.

# %% [markdown]
# 19.
# Store the number `42` in a variable and print whether it is equal to `42` using a boolean expression.

# %% [markdown]
# 20.
# Create two variables `x = 10` and `y = 20` and print the result of `x > y`.

# %% [markdown]
# 21.
# Write an `if` statement that prints `x is positive` if `x = 3` is greater than `0`.

# %% [markdown]
# 22.
# Write code that prints `True` if `5` is less than `10` and `False` otherwise.

# %% [markdown]
# 23.
# Using two boolean variables `is_raining = True` and `have_umbrella = False`, print the result of `is_raining and have_umbrella`.

# %% [markdown]
# 24.
# Write a program that reads a number from the user with `input()`, casts it to `int`, adds `5`, and prints the result.

# %% [markdown]
# 26.
# Create a variable `pi` with value `3.14159` and print a string `Pi is 3.14159` using an f-string.

# %% [markdown]
# 27.
# Given `x = 5`, update `x` using `x += 3` and print the new value.

# %% [markdown]
# 28.
# Create a variable `text = "  Python  "` and print it without leading or trailing spaces using a string method.

# %% [markdown]
# 29.
# Given `message = "PYTHON"`, print it in lowercase, then print it in title case (first letter uppercase).

# %% [markdown]
# 30. Write a program that defines two variables `a = True` and `b = False`, and prints the results of `a and b`, `a or b`, and `not a` on separate lines.

# %%
print(7.4//2)
# Out:
# 3.0

# %%
var1, var2 = 5,3

print(var1, var2)
# Out:
# 5 3

# %%
x = 5

print(x==5 and x == 6)
# Out:
# False

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]


x1 = ""
print(x is y)
# Out:
# False

# %%
print("Hello World")
# Out:
# Hello World

# %%
name = "John"
age = 20
height = 1.75
print("My name is", name, "and I am", age, "years old and my height is", height, "meters.")
# Out:
# My name is John and I am 20 years old and my height is 1.75 meters.

# %%
#Good:
student_name = "Anna"
#Bad:
x = "Anna"

# %%
age = 67
type(age)
# Out:
# int

# %%
print(10 % 3)   
# Output: 1
# Out:
# 1

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
print("Hello", name + "!", "You are", age, "years old.")

# %%
message = "Hello"
print(message[0])  # Output: H
print(message[1])  # Output: e
# Out:
# H
# e

# %%
text = "python"
print(text.upper())     # PYTHON
print(text[0])          # p
print(text[::-1])       # nohtyp
# Out:
# PYTHON
# p
# nohtyp

# %%
fruits = ["apple", "banana", "orange"]

fruits.append("grape")
print(fruits)
print(fruits[0])  # Output: apple
print(fruits[1])  # Output: banana
# Out:
# ['apple', 'banana', 'orange', 'grape']
# apple
# banana

# %%
numbers = [3, 1, 5]
numbers.sort()
print(numbers)
# Out:
# [1, 3, 5]

# %%
age = 18

if age >= 18:
    print("You can vote")
# Out:
# You can vote

# %%
score = 75

if score >= 80:
    print("A")
elif score >= 70:
    print("B")
else:
    print("C")
# Out:
# B

# %%
age = 20
if age > 18 and age < 30:
    print("Young adult")
# Out:
# Young adult

# %%
# This is a comment

# %%
#Correct Indentation
if 5 > 2:
    print("Yes")
#Wrong Indentation:
if 5 > 2:
print("Yes") #Add spaces before print statement

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

if age >= 18:
    print(name, "is an adult")
else:
    print(name, "is a minor")
# Out:
# Elisha is an adult

# %%
# Out:
# 1

# %%
mylist = [1, 2, 3, 4, 5]
print(mylist[0])  # Output: 1
# Out:
# 1
