# %% [markdown]
# # **NumPy Practice Notebook (CBA Based)**
# ### Prepared by Ghany Elisha
#
# This notebook contains **8 competency‑based assessment (CBA) questions** to help beginners practice NumPy.
# Each question includes:
# - A real coding task
# - Hints
# - Suggested NumPy methods
#
# Students should attempt to solve the problem in the **code cell below each question**. Note that They will be checked on the **07th of March 2026**

# %% [markdown]
# ## Question 1: Creating a NumPy Array
# A teacher records the marks of 10 students in a Python list.
# Convert the list into a NumPy array and print the type of both the list and the NumPy array.
#
# **Hints:**
# - Create a Python list first.
# - Convert it into a NumPy array.
# - Use print(type()) to check the types.
#
# **Useful Methods:** np.array(), type()

# %%
# Write your solution here

# %% [markdown]
# ## Question 2: Array Multiplication
# Create a NumPy array containing numbers from 1 to 10. Multiply the array by itself and print the result.
#
# **Hints:**
# - Use range() to generate numbers.
# - Convert the list into a NumPy array.
# - Multiply the array using the * operator.
#
# **Useful Methods:** range(), np.array(), array * array

# %%
# Write your solution here

# %% [markdown]
# ## Question 3: 2D Array Creation
# Create three lists representing rows of numbers. Combine them into a 3x3 NumPy array and print the array.
#
# **Hints:**
# - Create three lists like [1,2,3], [4,5,6], [7,8,9].
# - Pass the lists inside np.array().
#
# **Useful Methods:** np.array()

# %%
# Write your solution here

# %% [markdown]
# ## Question 4: Indexing Elements
# Using a 3x3 NumPy array, print the element in the last row and last column.
#
# **Hints:**
# - Rows and columns start at index 0.
# - The last element in a 3x3 matrix is at position [2,2].
#
# **Useful Methods:** array[row, column]

# %%
# Write your solution here

# %% [markdown]
# ## Question 5: Array Reshaping
# Create a NumPy array with numbers from 1 to 9 and reshape it into a 3x3 matrix.
#
# **Hints:**
# - Create a list of 9 numbers.
# - Convert it to NumPy array.
# - Use reshape(3,3).
#
# **Useful Methods:** np.array(), reshape()

# %%
# Write your solution here

# %% [markdown]
# ## Question 6: Array Properties
# Create a NumPy array and print the following properties:
# 1. Shape
# 2. Size
# 3. Number of dimensions
#
# **Hints:**
# - Create any NumPy array.
# - Use the attributes .shape, .size, and .ndim.
#
# **Useful Methods:** array.shape, array.size, array.ndim

# %%
# Write your solution here

# %% [markdown]
# ## Question 7: Creating Special Arrays
# Create the following arrays:
# 1. A 3x3 array of zeros
# 2. A 3x3 array of ones
# 3. A 4x4 array filled with the value 5
#
# **Hints:**
# - NumPy has built‑in functions for creating arrays.
# - Each function requires the shape of the array.
#
# **Useful Methods:** np.zeros(), np.ones(), np.full()

# %%
# Write your solution here

# %% [markdown]
# ## Question 8: Handling Missing Values
# Create a NumPy array containing numbers and some NaN values. Replace the NaN values with the mean of the valid numbers.
#
# **Hints:**
# - Use np.isnan() to detect missing values.
# - Use np.mean() with np.isfinite() to calculate mean.
# - Assign the mean to the NaN positions.
#
# **Useful Methods:** np.isnan(), np.mean(), np.isfinite()

# %%
# Write your solution here
